# %%
import pandas as pd
import pandas as pd
from sklearn.model_selection import train_test_split

# Load datasets
files = {
    # Profile / user-level finance
    "finance_expenses": "../data/profile/personal_finance_expenses.csv",
    "finance_tracker": "../data/profile/personal_finance_tracker_dataset.csv",
}

dfs = {name: pd.read_csv(path) for name, path in files.items()}

# Show quick info
for name, df in dfs.items():
    print(f"\n===== {name.upper()} =====")
    print("Shape:", df.shape)
    print("Columns:", df.columns.tolist())
    print("Missing values:\n", df.isnull().sum())
    print(df.head(3))
# Out:
# ===== FINANCE_EXPENSES =====
# Shape: (20000, 27)
# Columns: ['Income', 'Age', 'Dependents', 'Occupation', 'City_Tier', 'Rent', 'Loan_Repayment', 'Insurance', 'Groceries', 'Transport', 'Eating_Out', 'Entertainment', 'Utilities', 'Healthcare', 'Education', 'Miscellaneous', 'Desired_Savings_Percentage', 'Desired_Savings', 'Disposable_Income', 'Potential_Savings_Groceries', 'Potential_Savings_Transport', 'Potential_Savings_Eating_Out', 'Potential_Savings_Entertainment', 'Potential_Savings_Utilities', 'Potential_Savings_Healthcare', 'Potential_Savings_Education', 'Potential_Savings_Miscellaneous']
# Missing values:
#  Income                             0
# Age                                0
# Dependents                         0
# Occupation                         0
# City_Tier                          0
# Rent                               0
# Loan_Repayment                     0
# Insurance                          0
# Groceries                          0
# ...

# %%
# 1) Use preloaded finance_expenses
df = dfs["finance_expenses"]

# 2) Recreate engineered features exactly as before
expense_cols = [
    'Rent','Loan_Repayment','Insurance','Groceries','Transport','Eating_Out',
    'Entertainment','Utilities','Healthcare','Education','Miscellaneous'
]
df['total_expenses']     = df[expense_cols].sum(axis=1)
df['estimated_savings']  = df['Income'] - df['total_expenses']

# 3) Target and features
y = df['Desired_Savings']
X = df.drop(['Desired_Savings', 'Disposable_Income', 'estimated_savings'] + 
            [c for c in df.columns if 'Potential_Savings' in c], axis=1)

# 4) One-hot encode
X = pd.get_dummies(X, columns=['Occupation','City_Tier'])

# 5) Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %%
# 1) Use preloaded finance_tracker
df2 = dfs["finance_tracker"]

# 2) No derived features needed here (already includes actual_savings, income, expenses, etc.)

# 3) Target and features
y2 = df2['actual_savings']
X2 = df2.drop(['actual_savings', 'user_id', 'date', 'savings_goal_met'], axis=1)

# 4) One-hot encode
X2 = pd.get_dummies(X2, columns=[
    'financial_scenario', 
    'income_type', 
    'category',
    'cash_flow_status', 
    'financial_stress_level'
])

# 5) Train/test split
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, test_size=0.20, random_state=42
)

# %%
import joblib

# Load models
model_exp = joblib.load("../models/desired_savings_reg.pkl")
model_trk_xgb = joblib.load("../models/actual_savings_reg.pkl")

# Load column names
columns_exp = joblib.load("../models/desired_savings_columns.pkl")
columns_trk = joblib.load("../models/actual_savings_columns.pkl")

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_linear_coefficients(model, feature_names, title="Linear Coefficients"):
    coefs = pd.Series(model.coef_, index=feature_names)
    coefs = coefs.sort_values()

    plt.figure(figsize=(8, 6))
    coefs.plot(kind='barh')
    plt.title(title)
    plt.xlabel("Coefficient")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_xgb_feature_importance(model, feature_names, title="XGBoost Feature Importance"):
    importance = pd.Series(model.feature_importances_, index=feature_names)
    importance = importance.sort_values(ascending=True)

    plt.figure(figsize=(8, 6))
    importance.plot(kind='barh')
    plt.title(title)
    plt.xlabel("Importance")
    plt.tight_layout()
    plt.show()


# Function to save desired savings plot
def plot_linear_coefficients(model, feature_names, title="Linear Coefficients", save_path=None):
    import pandas as pd
    import matplotlib.pyplot as plt
    
    coefs = pd.Series(model.coef_, index=feature_names)
    coefs = coefs.sort_values()

    plt.figure(figsize=(8, 6))
    coefs.plot(kind='barh')
    plt.title(title)
    plt.xlabel("Coefficient")
    plt.grid(True)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300)
        print(f"Saved plot to {save_path}")
    else:
        plt.show()

def plot_xgb_feature_importance(model, feature_names, title="XGBoost Feature Importance", save_path=None):
    import pandas as pd
    import matplotlib.pyplot as plt
    
    importance = pd.Series(model.feature_importances_, index=feature_names)
    importance = importance.sort_values(ascending=True)

    plt.figure(figsize=(8, 6))
    importance.plot(kind='barh')
    plt.title(title)
    plt.xlabel("Importance")
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300)
        print(f"Saved plot to {save_path}")
    else:
        plt.show()

# %%
plot_linear_coefficients(model_exp, X.columns, "Linear Coefficients – Desired Savings")

# Positive drivers: Desired_Savings_Percentage, Dependents, Occupation_Self_Employed → these increase how much people want to save.
# Negative drivers: City_Tier_Tier_3, City_Tier_Tier_2 → people in smaller cities tend to desire less savings.
# Income also has some positive weight (as expected).

# Desired savings: influenced by psychological/demographic factors.

# %%
import pandas as pd

# Save coefficients
coefs = pd.Series(model_exp.coef_, index=columns_exp)
coefs.sort_values().to_csv("../models/desired_savings_coefficients.csv")
print("Saved desired savings coefficients.")

# Save Plot
plot_linear_coefficients(
    model_exp, columns_exp,
    "Linear Coefficients – Desired Savings",
    save_path="../models/desired_savings_coefficients.png"
)
# Out:
# Saved desired savings coefficients.
# Saved plot to ../models/desired_savings_coefficients.png

# %%
plot_xgb_feature_importance(model_trk_xgb, columns_trk, "XGBoost Feature Importance – Actual Savings")

# Top driver: monthly_income (dominant, makes sense).
# Also important: monthly_expense_total, budget_goal, rent_or_mortgage.
# Smaller contributors: discretionary spending, credit score, emergency fund, stress level.

# Actual savings: dictated by financial realities.

# %%
# Save feature importances
importances = pd.Series(model_trk_xgb.feature_importances_, index=columns_trk)
importances.sort_values(ascending=False).to_csv("../models/actual_savings_importances.csv")
print("Saved actual savings feature importances.")

plot_xgb_feature_importance(
    model_trk_xgb, columns_trk,
    "XGBoost Feature Importance – Actual Savings",
    save_path="../models/actual_savings_importances.png"
)
# Out:
# Saved actual savings feature importances.
# Saved plot to ../models/actual_savings_importances.png
